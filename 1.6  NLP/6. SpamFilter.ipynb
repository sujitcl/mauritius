# %% [markdown]
# # Spam Filter using  Naive Bayes

# %% [markdown]
# We'll start by using sklearn.naive_bayes to train a spam classifier! Most of the code is just loading our training data into a pandas DataFrame that we can play with:

# %%
import os
import io
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)

            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                elif line == '\n':
                    inBody = True
            f.close()
            message = '\n'.join(lines)
            yield path, message


def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

data = DataFrame({'message': [], 'class': []})

data = data.append(dataFrameFromDirectory('/Data/emails/spam', 'spam'))
data = data.append(dataFrameFromDirectory('/Data/emails/ham', 'ham'))

# %% [markdown]
# Let's have a look at that DataFrame:

# %%
data.message.head(10)

# %% [markdown]
# Now we will use a CountVectorizer to split up each message into its list of words, and throw that into a MultinomialNB classifier. Call fit() and we've got a trained spam filter ready to go! It's just that easy.

# %%
data.shape

# %%
data['class'].value_counts()

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)

classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)

# %%
len(vectorizer.vocabulary_)

# %% [markdown]
# Let's try it out:

# %%
examples = ['Free Viagra now!!!', 
            "Hi Bob, how about a game of golf tomorrow?",
           "Get discounts on medicines and free offer if you buy movies.",
           "GIFTING you FREE now"]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['spam', 'ham', 'spam', 'spam'], dtype='<U4')

# %%
examples = ["Protect your family's financial future from GreatOffers.com"]

example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['spam'], dtype='<U4')

# %% [markdown]
# ## Train Test Split and Accuracy

# %% [markdown]
# Our data set is small, so our spam classifier isn't actually very good. Try running some different test emails through it and see if you get the results you expect.
#
# If you really want to challenge yourself, try applying train/test to this spam classifier - see how well it can predict some subset of the ham and spam emails.

# %%
len(vectorizer.vocabulary_)
# Out:
# 62964

# %%
vectorizer.vocabulary_
# Out:
# {'doctype': 20407,
#  'html': 28844,
#  'public': 44554,
#  'w3c': 57486,
#  'dtd': 21111,
#  'transitional': 54131,
#  'en': 22319,
#  'head': 27856,
#  'meta': 36946,
#  'content': 17466,
#  '3d': 3669,
#  'text': 53112,
#  'charset': 15912,
#  '3dwindows': 3865,
#  '1252': 1193,
#  'http': 28855,
#  'equiv': 22714,
#  '3dcontent': 3777,
#  'ype': 60830,
#  'mshtml': 38010,
#  '00': 0,
#  '2314': 2507,
#  '1000': 878,
#  'name': 38606,
#  '3dgenerator': 3793,
#  'body': 13853,
#  'inserted': 30798,
#  'by': 14755,
#  'calypso': 15154,
#  'table': 52559,
#  'border': 13981,
#  '3d0': 3670,
#  'cellpadding': 15671,
#  'cellspacing': 15676,
#  '3d2': 3687,
#  'id': 29548,
#  '3d_calyprintheader_': 3751,
#  'ules': 55210,
#  '3dnone': 3822,
#  'style': 51599,
#  'color': 16855,
#  'black': 13539,
#  'display': 20085,
#  'none': 39475,
#  'width': 58579,
#  '100': 877,
#  'tbody': 52779,
#  'tr': 54034,
#  'td': 52828,
#  'colspan': 16868,
#  '3d3': 3701,
#  'hr': 28772,
#  '3dblack': 3768,
#  'noshade': 39549,
#  'size': 50047,
#  '3d1': 3672,
#  'end': 22373,
#  'font': 24768,
#  '000000': 3,
#  'face': 23667,
#  '3dverdana': 3861,
#  'arial': 11331,
#  'helvetica': 27996,
#  'br': 14136,
#  'ff0000': 24116,
#  'copperplate': 17612,
#  'gothic': 26686,
#  'bold': 13884,
#  '3d5': 3724,
#  'ptsize': 44529,
#  '10': 876,
#  'center': 15695,
#  'save': 48692,
#  'up': 55771,
#  'to': 53745,
#  '70': 6075,
#  'on': 40661,
#  'life': 34876,
#  'insurance': 30883,
#  'ff': 24112,
#  '0000': 2,
#  'why': 58553,
#  'spend': 50849,
#  'more': 37734,
#  'than': 53203,
#  'you': 60793,
#  'have': 27728,
#  'pt': 44494,
#  'quote': 45595,
#  'savings': 48702,
#  'align': 10408,
#  '3dleft': 3807,
#  'bordercolor': 13984,
#  '111111': 1059,
#  'wi': 58557,
#  'dth': 21113,
#  '3d650': 3737,
#  '35': 3455,
#  '3d4': 3713,
#  'ensurin': 22510,
#  'your': 60804,
#  'family': 23780,
#  'financial': 24331,
#  'security': 49146,
#  'is': 31369,
#  'very': 56678,
#  'important': 30330,
#  'ma': 35977,
#  'kes': 33208,
#  'buying': 14653,
#  'simple': 49939,
#  'and': 10746,
#  'affordable': 9799,
#  'we': 58215,
#  'provide': 44370,
#  'free': 25116,
#  'access': 9233,
#  'the': 53220,
#  'best': 13116,
#  'companies': 17002,
#  'lowest': 35476,
#  'rates': 46065,
#  '3dmiddle': 3811,
#  'valign': 56418,
#  '3dtop': 3855,
#  '18': 1609,
#  'padding': 41654,
#  'left': 34551,
#  '5px': 5364,
#  'right': 47451,
#  'fast': 23837,
#  'eas': 21614,
#  'saves': 48698,
#  'money': 37658,
#  'let': 34648,
#  'us': 55923,
#  'help': 27983,
#  'get': 26143,
#  'started': 51189,
#  'with': 58736,
#  'val': 56401,
#  'ues': 55008,
#  'in': 30375,
#  'country': 17757,
#  'new': 39016,
#  'coverage': 17792,
#  'can': 15189,
#  'hundreds': 28927,
#  'or': 40892,
#  'even': 23027,
#  'tho': 53344,
#  'usands': 55936,
#  'of': 40368,
#  'dollars': 20454,
#  'requesting': 46975,
#  'from': 25222,
#  'lifequote': 34887,
#  'our': 41145,
#  'service': 49377,
#  'will': 58615,
#  'take': 52619,
#  'less': 34640,
#  'minutes': 37298,
#  'complete': 17074,
#  'shop': 49715,
#  'an': 10697,
#  'compare': 17015,
#  'all': 10430,
#  'types': 54661,
#  'height': 27953,
#  '3d50': 3725,
#  '3dcenter': 3774,
#  'href': 28785,
#  'website': 58279,
#  'e365': 21458,
#  'cc': 15532,
#  'savequote': 48695,
#  'click': 16462,
#  'here': 28034,
#  'for': 24806,
#  'strong': 51534,
#  'protecting': 44331,
#  'investment': 31138,
#  'll': 35171,
#  'eve': 23025,
#  'make': 36177,
#  'sans': 48622,
#  'serif': 49346,
#  'if': 29783,
#  'are': 11302,
#  'receipt': 46344,
#  'this': 53337,
#  'email': 22197,
#  'error': 22787,
#  'wish': 58727,
#  'be': 12870,
#  'removed': 46819,
#  'list': 35030,
#  'mailto': 36134,
#  'coins': 16777,
#  'btamail': 14434,
#  'net': 38953,
#  'cn': 16635,
#  'please': 43219,
#  'type': 54656,
#  'remove': 46816,
#  'reside': 47038,
#  'any': 10966,
#  'state': 51216,
#  'which': 58467,
#  'prohibits': 44217,
#  'mail': 36099,
#  'solicitations': 50553,
#  'insuran': 30882,
#  'ce': 15629,
#  'disregard': 20104,
#  'fight': 24269,
#  'risk': 47502,
#  'cancer': 15202,
#  'www': 59298,
#  'adclick': 9481,
#  'ws': 59155,
#  'cfm': 15767,
#  '315': 3331,
#  'pk007': 43097,
#  'slim': 50225,
#  'down': 20582,
#  'guaranteed': 27093,
#  'lose': 35421,
#  '12': 1159,
#  'lbs': 34402,
#  '30': 3248,
#  'days': 18823,
#  '249': 2606,
#  'child': 16026,
#  'support': 51916,
#  'deserve': 19423,
#  'legal': 34561,
#  'advice': 9646,
#  '245': 2601,
#  'pk002': 43096,
#  'join': 32413,
#  'web': 58240,
#  'fastest': 23840,
#  'growing': 26986,
#  'singles': 49982,
#  'community': 16990,
#  '259': 2656,
#  'start': 51187,
#  'private': 44066,
#  'photo': 42831,
#  'album': 10360,
#  'online': 40687,
#  '283': 2795,
#  'wonderful': 58917,
#  'day': 18816,
#  'offer': 40397,
#  'manager': 36236,
#  'prizemama': 44085,
#  'leave': 34523,
#  'use': 55948,
#  'link': 34988,
#  'below': 13037,
#  'qves': 45616,
#  'com': 16881,
#  'trim': 54268,
#  'ilug': 30190,
#  'linux': 35006,
#  'ie': 29737,
#  '7c17': 6379,
#  '7c114258': 6377,
#  'irish': 31325,
#  'users': 55977,
#  'group': 26976,
#  'mailman': 36126,
#  'listinfo': 35061,
#  'un': 55293,
#  'subscription': 51682,
#  'information': 30646,
#  'maintainer': 36161,
#  'listmaster': 35065,
#  'zzzz': 62117,
#  'spamassassin': 50724,
#  'taint': 52610,
#  'org': 40934,
#  '7c308417': 6383,
#  'adult': 9609,
#  'club': 16551,
#  'offers': 40404,
#  'membership': 36848,
#  'instant': 30846,
#  'sites': 50022,
#  'now': 39611,
#  'user': 55963,
#  'password': 41940,
#  '760382': 6234,
#  'internet': 30993,
#  'news': 39037,
#  '08': 434,
#  '02': 220,
#  'just': 32663,
#  'over': 41244,
#  'million': 37215,
#  'members': 36847,
#  'that': 53213,
#  'signed': 49887,
#  'last': 34285,
#  'month': 37696,
#  'there': 53273,
#  'were': 58362,
#  '721': 6137,
#  '184': 1634,
#  'one': 40674,
#  'them': 53245,
#  'yet': 60523,
#  'faq': 23798,
#  'offering': 40402,
#  'advertisers': 9639,
#  'pay': 42020,
#  'me': 36728,
#  'ad': 9442,
#  'space': 50698,
#  'so': 50467,
#  'don': 20486,
#  'it': 31468,
#  'true': 54340,
#  'my': 38346,
#  'absolutely': 9136,
#  'never': 39011,
#  'cent': 15692,
#  'do': 20378,
#  'give': 26354,
#  'account': 9275,
#  'friends': 25196,
#  'yes': 60518,
#  'as': 11446,
#  'long': 35363,
#  'they': 53295,
#  'age': 9882,
#  'sign': 49879,
#  'no': 39398,
#  'how': 28711,
#  'following': 24751,
#  'links': 34997,
#  'become': 12916,
#  'member': 36846,
#  'these': 53287,
#  'multi': 38139,
#  'dollar': 20453,
#  'operations': 40787,
#  'policies': 43434,
#  'rules': 48094,
#  'fill': 24303,
#  'required': 46978,
#  'info': 30630,
#  'won': 58914,
#  'charge': 15895,
#  'pass': 41914,
#  'believe': 13008,
#  'read': 46235,
#  'their': 53242,
#  'terms': 53055,
#  'conditions': 17201,
#  'adults': 9612,
#  'farm': 23812,
#  '80': 6630,
#  '71': 6107,
#  '66': 5656,
#  'aid': 10075,
#  'girls': 26344,
#  'animals': 10809,
#  'getting': 26160,
#  'freaky': 25109,
#  'lifetime': 34892,
#  'sexy': 49449,
#  'celebes': 15650,
#  'celebst': 15658,
#  'thousands': 53366,
#  'xxx': 60139,
#  'doing': 20443,
#  'play': 43193,
#  'house': 28698,
#  'porn': 43529,
#  'mega': 36811,
#  'live': 35097,
#  'feeds': 24026,
#  '60': 5508,
#  'cams': 15187,
#  'asian': 11490,
#  'sex': 49436,
#  'fantasies': 23792,
#  'japanese': 31924,
#  'schoolgirls': 48865,
#  'shows': 49772,
#  'lesbian': 34636,
#  'lace': 34181,
#  'jennifer': 32094,
#  'simpson': 49948,
#  'miami': 37093,
#  'fl': 24481,
#  'has': 27681,
#  'entertained': 22527,
#  'boyffriend': 14082,
#  'two': 54604,
#  'years': 60488,
#  'joe': 32390,
#  'morgan': 37745,
#  'manhattan': 36260,
#  'ny': 39912,
#  'unbelievable': 55321,
#  'part': 41863,
#  'about': 9111,
#  're': 46220,
#  'removal': 46815,
#  'instructions': 30865,
#  'received': 46347,
#  'advertisement': 9636,
#  'because': 12912,
#  'opted': 40830,
#  'receive': 46346,
#  'specials': 50803,
#  'through': 53394,
#  'affiliated': 9785,
#  'websites': 58280,
#  'not': 39557,
#  'further': 25439,
#  'emails': 22205,
#  'may': 36539,
#  'opt': 40827,
#  'out': 41155,
#  'database': 18764,
#  'optout': 40860,
#  'allow': 10463,
#  '24': 2584,
#  'hours': 28697,
#  'vonolmosatkirekpups': 57137,
#  'thought': 53362,
#  'might': 37165,
#  'like': 34918,
#  'freeyankee': 25153,
#  'cgi': 15796,
#  'fy2': 25537,
#  '822slim1': 6740,
#  '822nic1': 6738,
#  '822ppl1': 6739,
#  'daily': 18663,
#  'deals': 18970,
#  'social': 50492,
#  '7c29': 6380,
#  '7c134077': 6378,
#  'events': 23034,
#  'powerhouse': 43688,
#  'gifting': 26298,
#  'program': 44193,
#  'want': 57713,
#  'miss': 37355,
#  'founders': 24957,
#  'major': 36170,
#  'players': 43198,
#  'once': 40669,
#  'where': 58455,
#  'invitation': 31147,
#  'experts': 23342,
#  'calling': 15141,
#  'way': 57825,
#  'huge': 28878,
#  'cash': 15393,
#  'flow': 24598,
#  'ever': 23037,
#  'conceived': 17153,
#  'leverage': 34676,
#  '000': 1,
#  'into': 31051,
#  '50': 4826,
#  'again': 9870,
#  'question': 45544,
#  'either': 22008,
#  'wealthy': 58232,
#  'am': 10556,
#  'tossing': 53898,
#  'lifeline': 34884,
#  'sake': 48526,
#  'hope': 28614,
#  'grab': 26793,
#  'onto': 40714,
#  'hold': 28504,
#  'tight': 53477,
#  'ride': 47432,
#  'testimonials': 53099,
#  'hear': 27900,
#  'what': 58431,
#  'average': 11951,
#  'people': 42370,
#  'first': 24403,
#  'few': 24107,
#  've': 56560,
#  'al': 10318,
#  'single': 49979,
#  'mother': 37790,
#  'was': 57773,
#  'sure': 51939,
#  'when': 58452,
#  'sent': 49287,
#  'off': 40387,
#  'pledge': 43226,
#  'but': 14632,
#  'got': 26682,
#  'back': 12462,
#  'next': 39089,
#  'ky': 33965,
#  'didn': 19769,
#  'found': 24951,
#  'myself': 38379,
#  'partner': 41900,
#  'work': 58962,
#  'think': 53319,
#  'made': 36040,
#  'decision': 19035,
#  'pick': 42903,
#  'gave': 25893,
#  'leads': 34496,
#  'training': 54090,
#  'too': 53838,
#  'ca': 15038,
#  'announcing': 10853,
#  'close': 16524,
#  'sales': 48537,
#  'fax': 23885,
#  'blast': 13575,
#  'immediately': 30260,
#  'upon': 55814,
#  'entry': 22567,
#  'wait': 57640,
#  'call': 15132,
#  '800': 6631,
#  '421': 4238,
#  '6318': 5590,
#  '896': 7272,
#  '6568': 5647,
#  'name__________________________________phone___________________________________________': 38612,
#  'fax_____________________________________email____________________________________________': 23887,
#  'time': 53506,
#  'call_________________________time': 15133,
#  'zone________________________________________': 61743,
#  'message': 36932,
#  'compliance': 17084,
#  'bill': 13359,
#  'per': 42376,
#  'section': 49126,
#  '301': 3259,
#  'paragraph': 41791,
#  '1618': 1488,
#  'transmissions': 54149,
#  'sender': 49256,
#  'stopped': 51399,
#  'at': 11640,
#  'cost': 17699,
#  'sending': 49262,
#  'reply': 46908,
#  'address': 9506,
#  'word': 58950,
#  'subject': 51641,
#  'line': 34965,
#  'errors': 22788,
#  'omissions': 40632,
#  'exceptions': 23166,
#  'excluded': 23185,
#  'spam': 50713,
#  'compiled': 17056,
#  'replicate': 46904,
#  'relative': 46709,
#  'seattle': 49096,
#  'marketing': 36376,
#  'gigt': 26310,
#  'turbo': 54487,
#  'team': 52860,
#  'sole': 50549,
#  'purpose': 44648,
#  'communications': 16982,
#  'continued': 17487,
#  'inclusion': 30436,
#  'only': 40694,
#  'gracious': 26802,
#  'permission': 42450,
#  'send': 49254,
#  'tesrewinter': 53085,
#  'yahoo': 60362,
#  'deleted': 19214,
#  'wanted': 57714,
#  '14': 1319,
#  'year': 60483,
#  'old': 40572,
#  'fortune': 24925,
#  '500': 4827,
#  'company': 17005,
#  'tremendous': 54226,
#  'rate': 46062,
#  'looking': 35377,
#  'individuals': 30548,
#  'who': 58522,
#  'home': 28535,
#  'opportunity': 40808,
#  'excellent': 23158,
#  'income': 30438,
#  'experience': 23326,
#  'train': 54086,
#  'employed': 22285,
#  'career': 15311,
#  'vast': 56480,
#  'opportunities': 40807,
#  'then': 53254,
#  'go': 26583,
#  'basetel': 12693,
#  'wealthnow': 58231,
#  'energetic': 22412,
#  'self': 49220,
#  'motivated': 37799,
#  'form': 24878,
#  'employement': 22289,
#  'specialist': 50797,
#  'contact': 17435,
#  '4139volw7': 4213,
#  '758dody1425frhm1': 6223,
#  '764smfc8513fcsll40': 6241,
#  'title': 53574,
#  'reliaquote': 46739,
#  'iso': 31418,
#  '8859': 7247,
#  'leftmargin': 34555,
#  'topmargin': 53865,
#  'ffcc99': 24140,
#  'vlink': 57028,
#  'alink': 10414,
#  'ffcc00': 24137,
#  '468': 4369,
#  'bgcolor': 13205,
#  '993366': 7873,
#  'top': 53851,
#  '43': 4265,
#  '56': 5048,
#  'theadmanager': 53225,
#  'server': 49372,
#  'asp': 11513,
#  'ad_key': 9458,
#  'yuesbhwakmlk': 60927,
#  'ext': 23410,
#  'target': 52703,
#  '_blank': 8375,
#  'img': 30239,
#  'src': 51038,
#  'banner': 12609,
#  'bannerads': 12611,
#  'images': 30210,
#  'logo6': 35338,
#  'gif': 26291,
#  '120': 1160,
#  '32': 3349,
#  '44': 4292,
#  'nbsp': 38740,
#  '377': 3548,
#  'ffccff': 24141,
#  'headline6': 27875,
#  '220': 2377,
#  '72': 6132,
#  '336699': 3409,
#  '34': 3425,
#  '45': 4324,
#  'tahoma': 52599,
#  'verdana': 56634,
#  'change': 15852,
#  'protect': 44329,
#  'future': 25454,
#  'sufficient': 51785,
#  'middle': 37149,
#  '27': 2729,
#  'freequotes6': 25140,
#  '177': 1587,
#  '3366cc': 3410,
#  '294': 2843,
#  'freequoteform': 25139,
#  'action': 9394,
#  'termlife': 53052,
#  'bin': 13375,
#  'banner_quote_resp': 12610,
#  'method': 36966,
#  'input': 30770,
#  'hidden': 28188,
#  'value': 56427,
#  '51100004022000000321': 4894,
#  'sourceid': 50661,
#  'class': 16382,
#  'hptbcolor': 28747,
#  'ffffff': 24155,
#  'residence': 47039,
#  '65': 5631,
#  'select': 49203,
#  'formscombobox12': 24899,
#  'option': 40850,
#  'selected': 49208,
#  'alabama': 10332,
#  'alaska': 10342,
#  'arizona': 11344,
#  'arkansas': 11347,
#  'california': 15130,
#  'colorado': 16856,
#  'connecticut': 17312,
#  'delaware': 19204,
#  'dc': 18872,
#  'dist': 20130,
#  'columbia': 16871,
#  'florida': 24593,
#  'georgia': 26117,
#  'hawaii': 27741,
#  'idaho': 29632,
#  'illinois': 30169,
#  'indiana': 30515,
#  'iowa': 31205,
#  'kansas': 33009,
#  'kentucky': 33183,
#  'louisiana': 35449,
#  'maine': 36149,
#  'maryland': 36429,
#  'massachusetts': 36445,
#  'michigan': 37111,
#  'minnesota': 37288,
#  'mississippi': 37367,
#  'missouri': 37369,
#  'montana': 37690,
#  'nebraska': 38835,
#  'nevada': 39010,
#  'hampshire': 27558,
#  'jersey': 32108,
#  'mexico': 36982,
#  'york': 60784,
#  'north': 39527,
#  'carolina': 15345,
#  'dakota': 18668,
#  'ohio': 40480,
#  'oklahoma': 40557,
#  'oregon': 40926,
#  'pennsylvania': 42356,
#  'rhode': 47380,
#  'island': 31406,
#  'south': 50669,
#  'tennessee': 53015,
#  'texas': 53111,
#  'utah': 56023,
#  'vermont': 56655,
#  'virginia': 56908,
#  'washington': 57778,
#  'west': 58368,
#  'wisconsin': 58722,
#  'wyoming': 59357,
#  'date': 18774,
#  'birth': 13417,
#  'mm': 37490,
#  'dd': 18919,
#  'yy': 61066,
#  'nowrap': 39616,
#  '01': 172,
#  '03': 279,
#  '04': 315,
#  '05': 345,
#  '06': 372,
#  '07': 396,
#  '09': 476,
#  '11': 1050,
#  '13': 1240,
#  '15': 1391,
#  '16': 1476,
#  '17': 1546,
#  '19': 1680,
#  '20': 2136,
#  '21': 2326,
#  '22': 2376,
#  '23': 2495,
#  '25': 2628,
#  '26': 2677,
#  '28': 2787,
#  '29': 2831,
#  '31': 3316,
#  '33': 3386,
#  '36': 3487,
#  '37': 3527,
#  '38': 3556,
#  '39': 3580,
#  '40': 4138,
#  '41': 4199,
#  '42': 4235,
#  '46': 4354,
#  '47': 4380,
#  '48': 4412,
#  '49': 4444,
#  '51': 4891,
#  '52': 4925,
#  '53': 4956,
#  '54': 4981,
#  '55': 5009,
#  '57': 5076,
#  '58': 5091,
#  '59': 5115,
#  '61': 5541,
#  '62': 5565,
#  '63': 5587,
#  '64': 5605,
#  '67': 5700,
#  '68': 5718,
#  '69': 5739,
#  '73': 6153,
#  '74': 6176,
#  '75': 6203,
#  '76': 6232,
#  '77': 6256,
#  '78': 6282,
#  '79': 6312,
#  '81': 6698,
#  '82': 6726,
#  '83': 6788,
#  '84': 6854,
#  'formsradiobutton1': 24900,
#  'radio': 45914,
#  'male': 36200,
#  'formsradiobutton2': 24901,
#  'female': 24060,
#  'used': 55951,
#  'tobacco': 53753,
#  'products': 44156,
#  'months': 37699,
#  'formsradiobutton4': 24903,
#  'formsradiobutton3': 24902,
#  'amount': 10660,
#  'formscombobox11': 24898,
#  '100000': 880,
#  '125000': 1191,
#  '125': 1189,
#  '150000': 1395,
#  '150': 1392,
#  '175000': 1578,
#  '175': 1577,
#  '200000': 2139,
#  '200': 2137,
#  '225000': 2426,
#  '225': 2423,
#  '250000': 2631,
#  '250': 2629,
#  '275000': 2763,
#  '275': 2761,
#  '300000': 3251,
#  '300': 3249,
#  '325000': 3366,
#  '325': 3365,
#  '350000': 3458,
#  '350': 3456,
#  '375000': 3545,
#  '375': 3544,
#  '400000': 4141,
#  '400': 4139,
#  '425000': 4250,
#  '425': 4249,
#  '450000': 4326,
#  '450': 4325,
#  '475000': 4394,
#  '475': 4393,
#  '500000': 4830,
#  '550000': 5012,
#  '550': 5010,
#  '600000': 5511,
#  '600': 5509,
#  '650000': 5634,
#  '650': 5632,
#  '700000': 6077,
#  '700': 6076,
#  '750000': 6206,
#  '750': 6204,
#  '800000': 6633,
#  '850000': 6939,
#  '850': 6938,
#  '900000': 7661,
#  '900': 7659,
#  '950000': 7774,
#  '950': 7772,
#  '1000000': 881,
#  '1250000': 1192,
#  '1500000': 1396,
#  '1750000': 1579,
#  '2000000': 2140,
#  '2250000': 2427,
#  '2500000': 2632,
#  '3000000': 3252,
#  '3500000': 3459,
#  '4000000': 4142,
#  '4500000': 4327,
#  '5000000': 4831,
#  '6000000': 5512,
#  '7000000': 6078,
#  '8000000': 6634,
#  '9000000': 7662,
#  '10000000': 882,
#  '11000000': 1053,
#  '12000000': 1163,
#  '13000000': 1243,
#  '14000000': 1322,
#  '15000000': 1397,
#  'need': 38853,
#  'formscombobox10': 24897,
#  'plan': 43159,
#  'formsbutton1': 24896,
#  'submit': 51660,
#  'submitbutton': 51661,
#  'photo6': 42832,
#  'jpg': 32494,
#  '210': 2327,
#  '173': 1568,
#  '217': 2356,
#  'div': 20186,
#  'makes': 36186,
#  'easy': 21627,
#  'instantly': 30849,
#  'quotes': 45598,
#  'highly': 28210,
#  'rated': 46063,
#  '106': 1012,
#  '70percent6': 6105,
#  '131': 1247,
#  'ffcc33': 24138,
#  'today': 53760,
#  '0000ff': 20,
#  'nothing': 39575,
#  'copyright': 17622,
#  '2001': 2143,
#  'inc': 30406,
#  'rights': 47459,
#  'reserved': 47029,
#  'admanmail': 9552,
#  'hspace': 28816,
#  'vspace': 57264,
#  'alt': 10515,
#  'receiving': 46352,
#  'mailing': 36120,
#  'sendgreatoffers': 49260,
#  'subscribed': 51677,
#  'jm': 32308,
#  'netnoteinc': 38978,
#  'unsubscribe': 55693,
#  'em': 22175,
#  'sgo': 49510,
#  'must': 38234,
#  'also': 10513,
#  'include': 30432,
#  'unsubscribed': 55695,
#  'correspondence': 17677,
#  'services': 49379,
#  'should': 49743,
#  'directed': 19894,
#  'tired': 53561,
#  'bull': 14539,
#  'stop': 51394,
#  'losing': 35426,
#  'real': 46257,
#  'maker': 36184,
#  'big': 13321,
#  'boys': 14085,
#  'system': 52291,
#  'drive': 21013,
#  'doorstep': 20524,
#  'short': 49726,
#  'period': 42415,
#  'most': 37784,
#  'print': 44034,
#  'successleads': 51742,
#  'firemail': 24385,
#  'de': 18948,
#  'telephone': 52960,
#  'number': 39789,
#  'responding': 47094,
#  '499': 4462,
#  '99': 7865,
#  'name___________________________________': 38607,
#  'phone___________________________________': 42821,
#  'fax_____________________________________': 23886,
#  'email___________________________________': 22199,
#  'dear': 18974,
#  'ricardo1': 47409,
#  'red': 46456,
#  'effective': 21866,
#  'direct': 19893,
#  'advertising': 9641,
#  'blue': 13693,
#  'promote': 44248,
#  'business': 14619,
#  'low': 35468,
#  'addresses': 9515,
#  '44c300': 4316,
#  'maximize': 36525,
#  '309': 3284,
#  '407': 4171,
#  '7378': 6165,
#  'consultant': 17418,
#  'discuss': 20017,
#  'needs': 38861,
#  ...}

# %%
from sklearn.model_selection import train_test_split,ShuffleSplit
X=counts
y=targets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
X_test.shape
# Out:
# (900, 62964)

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print ('Train Accuracy:{0: .3f}%'.format(classifier.score(X_train, y_train) * 100))
print ('Test Accuracy:{0: .3f}%'.format(classifier.score(X_test, y_test) * 100))
# Out:
# Train Accuracy: 97.762%
# Test Accuracy: 94.667%

# %% [markdown]
# ## Cleaning up HTML etc

# %%
from bs4 import BeautifulSoup

# %%
import re

# %%
def subst(text):
    
    soup = BeautifulSoup(text, 'html.parser')
    text = soup.get_text()
    return text
#re.sub("[^a-zA-Z]"," ",text)

# %%
data['cleanmsg']=data['message'].apply(subst)
# Out:
# D:\Anaconda3\envs\py37\lib\site-packages\bs4\__init__.py:398: UserWarning: "http://www.post-gazette.com/columnists/20020905brian5.asp
#
#
#
#
#
#
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   markup

# %%
data.head(10)
# Out:
#                                                                                               message  \
# /Data/emails/spam\00001.7848dde101aa985090474a9...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# /Data/emails/spam\00002.d94f1b97e48ed3b553b3508...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Data/emails/spam\00003.2ee33bc6eacdb11f38d052c...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Data/emails/spam\00004.eac8de8d759b7e74154f142...  ##############################################...
# /Data/emails/spam\00005.57696a39d7d84318ce49788...  I thought you might like these:\n\n1) Slim Dow...
# /Data/emails/spam\00006.5ab5620d3d7c6c0db762345...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# /Data/emails/spam\00007.d8521faf753ff9ee989122f...  Help wanted.  We are a 14 year old fortune 500...
# /Data/emails/spam\00008.dfd941deb10f5eed78b1594...  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# /Data/emails/spam\00009.027bf6e0b0c4ab34db3ce0e...  TIRED OF THE BULL OUT THERE?\n\nWant To Stop L...
# /Data/emails/spam\00010.445affef4c70feec58f9198...  Dear ricardo1 ,\n\n\n\n<html>\n\n<body>\n\n<ce...
#
#                                                    class  \
# /Data/emails/spam\00001.7848dde101aa985090474a9...  spam
# /Data/emails/spam\00002.d94f1b97e48ed3b553b3508...  spam
# /Data/emails/spam\00003.2ee33bc6eacdb11f38d052c...  spam
# /Data/emails/spam\00004.eac8de8d759b7e74154f142...  spam
# /Data/emails/spam\00005.57696a39d7d84318ce49788...  spam
# /Data/emails/spam\00006.5ab5620d3d7c6c0db762345...  spam
# /Data/emails/spam\00007.d8521faf753ff9ee989122f...  spam
# /Data/emails/spam\00008.dfd941deb10f5eed78b1594...  spam
# /Data/emails/spam\00009.027bf6e0b0c4ab34db3ce0e...  spam
# /Data/emails/spam\00010.445affef4c70feec58f9198...  spam
#
#                                                                                              cleanmsg
# /Data/emails/spam\00001.7848dde101aa985090474a9...  \n\n\n\n\n\n\n\n\n\n\n\n\n\n<=\n\n/TR>\nSave u...
# /Data/emails/spam\00002.d94f1b97e48ed3b553b3508...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Data/emails/spam\00003.2ee33bc6eacdb11f38d052c...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Data/emails/spam\00004.eac8de8d759b7e74154f142...  ##############################################...
# /Data/emails/spam\00005.57696a39d7d84318ce49788...  I thought you might like these:\n\n1) Slim Dow...
# /Data/emails/spam\00006.5ab5620d3d7c6c0db762345...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# /Data/emails/spam\00007.d8521faf753ff9ee989122f...  Help wanted.  We are a 14 year old fortune 500...
# /Data/emails/spam\00008.dfd941deb10f5eed78b1594...  \n\nReliaQuote - Save Up To 70% On Life Insura...
# /Data/emails/spam\00009.027bf6e0b0c4ab34db3ce0e...  TIRED OF THE BULL OUT THERE?\n\nWant To Stop L...
# /Data/emails/spam\00010.445affef4c70feec58f9198...  Dear ricardo1 ,\n\n\n\n\n\n\nCOST EFFECTIVE Di...

# %%
from sklearn.model_selection import train_test_split,ShuffleSplit
vectorizer = CountVectorizer(max_features=20000)
counts = vectorizer.fit_transform(data['cleanmsg'].values)

classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
X=counts
y=targets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

classifier.fit(X_train, y_train)
print ('Train Accuracy:{0: .3f}%'.format(classifier.score(X_train, y_train) * 100))
print ('Test Accuracy:{0: .3f}%'.format(classifier.score(X_test, y_test) * 100))
# Out:
# Train Accuracy: 99.810%
# Test Accuracy: 99.111%

# %%
len(vectorizer.vocabulary_)

# %%
examples = ['Free Viagra now!!!', 
            "Hi Bob, how about a game of golf tomorrow?",
           "Get discounts on medicines and free offer if you buy movies.",
           "GIFTING you FREE now"]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions

# %%
examples = ['Offers rush to nearest store to buy your favorite car', 
            "What is the status of the work ",
           "Unlock rewards for your awesome profile"]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
