# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import nltk

# %%
df = pd.read_csv('./Restaurant_Reviews.tsv', delimiter='\t', quoting=3)
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
# df_copy = pd.read_csv('Restaurant_Reviews.tsv', delimiter='\t', quoting=3)
df_copy = df.copy()

# %%
df_copy.shape
# Out:
# (1000, 2)

# %% [markdown]
# Stemming: Chops off the ends of words based on heuristis like 'SS' -> 'S'
# Lemmatization: Respects words and reduces to morphological root

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.stem import LancasterStemmer
#nltk.download('stopwords')

# %% [markdown]
# ### The original stop words block out the negatives - the above code creates a new stopwords sw which adds them back

# %%
#create a new variable sw containing  the stop words from sn but avoiding negative words
sn= set(stopwords.words('english'))

# %%
sn
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
negwords=["not","mustn","doesn","won't","wasn't","hadn't","shouldn't","shan't","doesn't","haven't","isn't","hasn't","needn","shouldn","didn","weren't","wouldn","mightn't","hadn","hasn","haven","couldn","needn't","didn't","wouldn't"]
sw=list()
for x in sn:
    if x not in negwords:
        sw.append(x)

# %%
#stemmer = PorterStemmer()
stemmer = SnowballStemmer("english")
#stemmer = LancasterStemmer("english")
def rep(review):
    review = re.sub('[^a-zA-Z]', ' ', review)
    review = review.lower()
    reviews = review.split()
    reviewsnew=list()
    #nlpreviews=nlp(review)
    reviews = [stemmer.stem(x) for x in reviews if x not in sw]
    # reviews = [x for x in reviews if x not in sw]
    review = ' '.join(reviews)
    return review

# %%
df['Review'] = df['Review'].apply(rep)
df.head()
# Out:
#                                               Review  Liked
# 0                                     wow love place      1
# 1                                     crust not good      0
# 2                             not tasti textur nasti      0
# 3  stop late may bank holiday rick steve recommen...      1
# 4                            select menu great price      1

# %%
corpus = df['Review'].tolist()
corpus[:10]
# Out:
# ['wow love place',
#  'crust not good',
#  'not tasti textur nasti',
#  'stop late may bank holiday rick steve recommend love',
#  'select menu great price',
#  'get angri want damn pho',
#  'honeslti didn tast fresh',
#  'potato like rubber could tell made ahead time kept warmer',
#  'fri great',
#  'great touch']

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()

# %%
X.shape
# Out:
# (1000, 1500)

# %%
y = df['Liked'].tolist()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

clf = GaussianNB()
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
print('Training accuracy : {0: .1f}% ' .format( 100*accuracy_score(y_train,y_train_pred)))

print ('Test Accuracy:{0: .1f}%'.format(clf.score(X_test, y_test) * 100))
# Out:
# Training accuracy :  92.4%
# Test Accuracy: 74.0%

# %% [markdown]
# ### Display the results

# %%
predictions = clf.predict(X)

# %%
pred=pd.DataFrame(predictions, columns=['Predicted'])

# %%
df_copy.join([ pred])
# Out:
#                                                 Review  Liked  Predicted
# 0                             Wow... Loved this place.      1          1
# 1                                   Crust is not good.      0          0
# 2            Not tasty and the texture was just nasty.      0          0
# 3    Stopped by during the late May bank holiday of...      1          1
# 4    The selection on the menu was great and so wer...      1          1
# 5       Now I am getting angry and I want my damn pho.      0          1
# 6                Honeslty it didn't taste THAT fresh.)      0          0
# 7    The potatoes were like rubber and you could te...      0          0
# 8                            The fries were great too.      1          1
# 9                                       A great touch.      1          1
# 10                            Service was very prompt.      1          1
# 11                                  Would not go back.      0          1
# 12   The cashier had no care what so ever on what I...      0          0
# 13   I tried the Cape Cod ravoli, chicken, with cra...      1          1
# 14   I was disgusted because I was pretty sure that...      0          0
# 15   I was shocked because no signs indicate cash o...      0          0
# 16                                 Highly recommended.      1          1
# 17              Waitress was a little slow in service.      0          0
# 18   This place is not worth your time, let alone V...      0          0
# 19                                did not like at all.      0          1
# 20                                 The Burrittos Blah!      0          0
# 21                                  The food, amazing.      1          1
# 22                               Service is also cute.      1          1
# 23   I could care less... The interior is just beau...      1          1
# 24                                  So they performed.      1          1
# 25   That's right....the red velvet cake.....ohhh t...      1          1
# 26          - They never brought a salad we asked for.      0          1
# 27   This hole in the wall has great Mexican street...      1          1
# 28   Took an hour to get our food only 4 tables in ...      0          0
# 29                   The worst was the salmon sashimi.      0          0
# ..                                                 ...    ...        ...
# 970  I immediately said I wanted to talk to the man...      0          0
# 971                    The ambiance isn't much better.      0          1
# 972  Unfortunately, it only set us up for disapppoi...      0          0
# 973                              The food wasn't good.      0          1
# 974  Your servers suck, wait, correction, our serve...      0          0
# 975      What happened next was pretty....off putting.      0          1
# 976  too bad cause I know it's family owned, I real...      0          0
# 977               Overpriced for what you are getting.      0          0
# 978               I vomited in the bathroom mid lunch.      0          0
# 979  I kept looking at the time and it had soon bec...      0          0
# 980  I have been to very few places to eat that und...      0          0
# 981  We started with the tuna sashimi which was bro...      0          0
# 982                            Food was below average.      0          0
# 983  It sure does beat the nachos at the movies but...      0          0
# 984       All in all, Ha Long Bay was a bit of a flop.      0          0
# 985  The problem I have is that they charge $11.99 ...      0          0
# 986  Shrimp- When I unwrapped it (I live only 1/2 a...      0          0
# 987     It lacked flavor, seemed undercooked, and dry.      0          0
# 988  It really is impressive that the place hasn't ...      0          0
# 989  I would avoid this place if you are staying in...      0          0
# 990  The refried beans that came with my meal were ...      0          0
# 991         Spend your money and time some place else.      0          0
# 992  A lady at the table next to us found a live gr...      0          0
# 993            the presentation of the food was awful.      0          1
# 994           I can't tell you how disappointed I was.      0          1
# 995  I think food should have flavor and texture an...      0          1
# 996                           Appetite instantly gone.      0          1
# 997  Overall I was not impressed and would not go b...      0          1
# 998  The whole experience was underwhelming, and I ...      0          0
# 999  Then, as if I hadn't wasted enough of my life ...      0          0
#
# [1000 rows x 3 columns]

# %%
# some mis-predictions could be because the critical word was not in the training set.

word = 'awful'
df['contains'] = df['Review'].apply(lambda x: 1 if word in x else 0)

# %%
df[df.contains == 1]
# Out:
# Empty DataFrame
# Columns: [Review, Liked, contains]
# Index: []
