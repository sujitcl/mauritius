# %% [markdown]
# # Introduction to Jupyter

# %% [markdown]
# ### Cells contain code

# %%
#  This is a cell in which you can write python code
print('hello world !')
print('hi')
# Out:
# hello world !
# hi

# %%
print('hello world !')
print('hi')
# Out:
# hello world !
# hi

# %%
# By clicking inside the cell, you can start to edit it. This is called EDIT Mode. And the outline color is GREEN

# %% [markdown]
# ### Command mode vs Edit mode

# %%
# By clicking anywhere outside the cell, or pressing ESCAPE, you can put the cell in COMMAND mode. This is called EDIT Mode. 
#And the outline color on the left side  is BLUE

# %% [markdown]
# Edit mode: When the highlighted cell is green the cell is in edit mode. You can edit your code now.
# <br>
# Command mode: When it is highlighted in blue the cell is in command mode. You can cut, copy, paste, add, remove selected cells.

# %% [markdown]
# ### How to Run a Cell
# * Two ways to execute a cell
#     - a) Use Run from the short cut menu above , or
#     - b) SHIFT + ENTER

# %%
# Press shift + enter to run this cell
print('Hello !')

print('Welcome to the world of ML !!')

# %%
# Press shift + enter to run this cell
print('Hello !')

print('Welcome to the world of ML !!')
# Out:
# Hello !
# Welcome to the world of ML !!

# %%
# When you see a '*' ie, In[*] that means that current cell is still procession.
# when you see a number inside it ie, In[1]. It means cell has finished execution.

# %% [markdown]
# ### Add a Empty cell below.
#
# #### Use can use  INSERT-> Cell Below from the menu or the <b>+ </b> button.  A short cut is to Press <i> b</i> after putting this cell in command mode.

# %%
### This is an cell. Add a empty cell above and below me

# %% [markdown]
# ### Delete selected cell.  Use the Scissor button, or Edit-> Delete
# #### Double tap d after putting this cell in command mode.

# %%
## Delete this cell

# %% [markdown]
# ### Undo actions by pressing z when in command mode. Ctrl+z in edit mode.

# %%
# Type something here and then press ctrl-Z

# %% [markdown]
# ### Important Commands from Menu:
#
# * File -> Close and Halt
#     This will close the notebook tab,  and FREE the server memory. Do this after every assignment. Do not just close the tab in the browser
#
# * Edit -> Cut , Copy, Paste, Delete
#   Self explanatory

# %% [markdown]
# ### Assignment : Visualization code - Run the cells below  repeatedly and observe the output

# %%
#visualization code

# %matplotlib inline
from pylab import imshow, show, get_cmap
from numpy import random

Z = random.random((100,100))   # Test data

imshow(Z, cmap=get_cmap("coolwarm"), interpolation='nearest')
show()

# %%
# Copy the visualization code from the above cell into the space below 
# Change the colormap from "coolwarm"  to "Blues"  and try again

# %%
# Change the values of the grid from (5,5) to other dimensions and watch the fun
